# %% [markdown]
# # Dropout : (randomly droping few neurons while training the ANN model)
# ## And balancing that dropout by scaling the weights in inference(prediction/testing)
#
#
# ### Inverted Dropout (used in Keras, TensorFlow, PyTorch, etc.)
#
# During training, when a neuron survives dropout, its output is scaled by 1 / (1 - p).
#
# Example: If p=0.5, surviving outputs are multiplied by 2.
#
# This way, the expected value of the neuron stays the same as without dropout.
#
# ✅ At test time, no scaling is needed → Dropout is simply turned off.
#
#
# #### Modern frameworks (TF/Keras, PyTorch) use inverted dropout, so scaling is handled automatically during training.

# %% [markdown]
# ### 1. Data Preprocessing

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

datasetPath = '../data/Churn_Modelling.csv'

# %% [markdown]
# ### Use the DagsHub client to setup connection information for MLflow
# ### MLFlow - for experiment tracking

# %%
import dagshub
import mlflow
import time


#mlflow.set_tracking_uri("http://127.0.0.1:5000")
dagshub.init(repo_owner='264Gaurav', repo_name='deep-learning', mlflow=True)

# Set the experiment name
mlflow.set_experiment("ANN-p2")


# Start an MLflow run to log this execution
with mlflow.start_run() as run:
    run_id = run.info.run_id
    print(f"MLflow Run ID: {run_id}")

    mlflow.log_param("data set path", datasetPath)

    start_time = time.time()
    dataset = pd.read_csv(datasetPath) # extracted_data will be a list of Document objects
    end_time = time.time()
    loading_duration = end_time - start_time

    mlflow.log_metric("num_documents_loaded", len(dataset))
    mlflow.log_metric("pdf_loading_duration_seconds", loading_duration)


    print(f"MLflow Run ID: {run_id}")
    print(f"MLflow run finished. View at {mlflow.get_tracking_uri()}")
# Out:
# Accessing as 264Gaurav
# Initialized MLflow to track repo "264Gaurav/deep-learning"
# Repository 264Gaurav/deep-learning initialized!
# MLflow Run ID: dbe8a729e7fa46cfa7895c720af638e4
# MLflow Run ID: dbe8a729e7fa46cfa7895c720af638e4
# MLflow run finished. View at https://dagshub.com/264Gaurav/deep-learning.mlflow
# 🏃 View run magnificent-moth-198 at: https://dagshub.com/264Gaurav/deep-learning.mlflow/#/experiments/3/runs/dbe8a729e7fa46cfa7895c720af638e4
# 🧪 View experiment at: https://dagshub.com/264Gaurav/deep-learning.mlflow/#/experiments/3

# %%
## Selects features (X) and target variable (y).
# iloc[:, 3:13] → takes columns 3 to 12 (customer info) as features.
# iloc[:, 13] → takes column 13 (whether the customer exited = churn) as labels.

X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %% [markdown]
# ### Replace categorical text data (Geography, Gender) with numeric columns that a (ANN) neural network can understand.
# #### get_dummies() converts categorical text values into numeric binary columns (one-hot encoding).

# %%
# Create dummy variables
geography = pd.get_dummies(X["Geography"], drop_first=True)
gender = pd.get_dummies(X['Gender'], drop_first=True)

# Concatenate the Data Frames
X = pd.concat([X, geography, gender], axis=1)

# Drop Unnecessary columns ## since, ANN needs numbers, not text so drop text/string columns
# Neural networks (and most ML algorithms) cannot work directly with text, they need numeric input.
# Solution: One-hot encoding (dummy variables)
X = X.drop(['Geography', 'Gender'], axis=1)

# %% [markdown]
# ### Splits the dataset into training (80%) and testing (20%) sets.

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split

testSetSize = 0.2
mlflow.log_param('Test set size', testSetSize)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=testSetSize, random_state=0
)

# %% [markdown]
# ### Feature scaling → standardizes data (mean = 0, std = 1).
#
# #### ANN performance improves when inputs are scaled.
#
# fit_transform → learns scaling from training data and applies it.
#
# transform → applies the same scaling to test data.

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## 2. Build the ANN!
#
# ### Import TensorFlow and Keras modules. (Now, keras is comes along with tensorflow 2.x)
#
# Sequential → linear stack of layers.
#
# Dense → fully connected (ANN) layer.
#
# Dropout → randomly drops neurons to reduce overfitting (optional).

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Initialising the ANN model as a sequential stack.
mlflow.log_param('ANN Model type', 'Sequential')
classifier = Sequential()

# %% [markdown]
# #### Adds the first hidden layer.
#
# units=6 → 6 neurons.
#
# kernel_initializer='he_uniform' → weight initialization method.
#
# activation='relu' → activation function (introduces non-linearity).
#
# input_dim=11 → number of input features (11 columns in X).

# %%
input_dim = X_train.shape[1]
units = 6
kernel_initializer = 'he_uniform'
activation = 'relu'
dropout = 0.3 # dropout to prevent overfitting and improve generalization of the model.

mlflow.log_param('input_dim', input_dim)
mlflow.log_param('units', units)
mlflow.log_param('kernel_initializer', kernel_initializer)
mlflow.log_param('activation', activation)
mlflow.log_param('Dropout value', dropout)

# Adding the input layer and the first hidden layer.
classifier.add(Dense(units=units, kernel_initializer=kernel_initializer ,activation=activation, input_dim=input_dim))
classifier.add(Dropout(dropout))
# Out:
# c:\Users\gaura\miniconda3\envs\ai\lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
sec_units = 6
sec_kernel_initializer = 'he_uniform'
sec_activation = 'relu'

# Adding the second hidden layer.
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
classifier.add(Dropout(dropout))


mlflow.log_param('Total neurons in second hidden layer', sec_units)
mlflow.log_param('Second hidden layer activation', sec_activation)
mlflow.log_param('Second hidden layer kernel_initializer', sec_kernel_initializer)
# Out:
# 'he_uniform'

# %%
# third_units = 6
# third_kernel_initializer = 'he_uniform'
# third_activation = 'relu'

# # Adding the second hidden layer.
# classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
# classifier.add(Dropout(dropout))


# mlflow.log_param('Total neurons in third hidden layer', third_units)
# mlflow.log_param('Third hidden layer activation', third_activation)
# mlflow.log_param('Third hidden layer kernel_initializer', third_kernel_initializer)

# %%
out_units = 1
out_activation = 'sigmoid'
out_kernel_initializer = 'glorot_uniform'

## Adds the output layer.
# units=1 → single output neuron (binary classification: churn or not).
# activation='sigmoid' → outputs probability between 0 and 1.
classifier.add(Dense(units=out_units, kernel_initializer=out_kernel_initializer, activation=out_activation))

mlflow.log_param('Output layer units', out_units)
mlflow.log_param('Output layer activation', out_activation)
mlflow.log_param('Output layer kernel_initializer', out_kernel_initializer)
# Out:
# 'glorot_uniform'

# %% [markdown]
# #### Compiles the ANN (sets training configuration).
#
# optimizer='adamax' → optimization algorithm.
#
# loss='binary_crossentropy' → loss function for binary classification.
#
# metrics=['accuracy'] → track accuracy during training.

# %%
optimizer = 'adamax'
loss = 'binary_crossentropy'
metrics = ['accuracy']

classifier.compile(optimizer='adamax', loss='binary_crossentropy', metrics=['accuracy'])

mlflow.log_param('optimizer for ANN', 'adamax')
mlflow.log_param('loss function for ANN', 'binary_crossentropy')
mlflow.log_param('metrics for ANN', metrics)
# Out:
# ['accuracy']

# %% [markdown]
# #### Trains the ANN on training data.
#
# validation_split=0.33 → uses 33% of training data for validation.
#
# batch_size=10 → updates weights after every 10 samples.
#
# epochs=100 → number of training iterations over the dataset.
#
# verbose=1 → prints progress.
#
# ###### model_history stores loss/accuracy values for plotting later.

# %% [markdown]
# ### classifier.fit(...)
#
# This is the method that trains the model on the data.
#
# It adjusts the weights of your ANN using backpropagation + optimizer (Adamax in our case).
#
# ### validation_split=0.33
#
# 33% of the training data is reserved for validation.
#
# Validation data is not used to train weights, only to check performance after each epoch.
#
# Helps detect overfitting (when training accuracy is high but validation accuracy is low).
#
# ### batch_size=10
#
# Training data is split into mini-batches of 10 samples.
#
# The ANN updates its weights after each batch (not after the whole dataset).
#
# Why? → Speeds up training and makes gradient descent more stable.
#
# ### epochs=100
#
# The model will go through the entire training dataset 100 times.
#
# More epochs = more chances to learn, but also risk of overfitting.
#
# Each epoch consists of multiple batch updates.
#
# ### verbose=1
#
# Controls the training output:
#
# 0 → silent
#
# 1 → progress bar for each epoch (default)
#
# 2 → one line per epoch
#
# ### model_history
#
# Stores training history in a dictionary format.

# %%
validation_split = 0.33
batch_size = 10
epochs = 100
verbose = 1

model_history = classifier.fit(
    X_train, y_train, validation_split=validation_split,
    batch_size=batch_size, epochs=epochs, verbose=verbose
)

mlflow.log_param('batch_size', batch_size)
mlflow.log_param('epochs', epochs)
mlflow.log_param('validation_split', validation_split)
mlflow.log_param('verbose', verbose)
# Out:
# Epoch 1/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7649 - loss: 0.6256 - val_accuracy: 0.8008 - val_loss: 0.5765
# Epoch 2/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7906 - loss: 0.5631 - val_accuracy: 0.7963 - val_loss: 0.5372
# Epoch 3/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.5402 - val_accuracy: 0.7955 - val_loss: 0.5167
# Epoch 4/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7953 - loss: 0.5274 - val_accuracy: 0.7955 - val_loss: 0.5035
# Epoch 5/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7959 - loss: 0.5142 - val_accuracy: 0.7952 - val_loss: 0.4946
# Epoch 6/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7957 - loss: 0.5044 - val_accuracy: 0.7952 - val_loss: 0.4871
# Epoch 7/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7964 - loss: 0.5017 - val_accuracy: 0.7952 - val_loss: 0.4828
# Epoch 8/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7979 - loss: 0.4982 - val_accuracy: 0.7955 - val_loss: 0.4786
# Epoch 9/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7959 - loss: 0.4992 - val_accuracy: 0.7952 - val_loss: 0.4760
# Epoch 10/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7949 - loss: 0.4862 - val_accuracy: 0.7955 - val_loss: 0.4719
# Epoch 11/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7968 - loss: 0.4860 - val_accuracy: 0.7955 - val_loss: 0.4692
# Epoch 12/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8009 - loss: 0.4796 - val_accuracy: 0.7955 - val_loss: 0.4658
# Epoch 13/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7968 - loss: 0.4806 - val_accuracy: 0.7967 - val_loss: 0.4632
# Epoch 14/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7985 - loss: 0.4820 - val_accuracy: 0.7970 - val_loss: 0.4614
# Epoch 15/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7996 - loss: 0.4795 - val_accuracy: 0.7974 - val_loss: 0.4598
# Epoch 16/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8035 - loss: 0.4734 - val_accuracy: 0.7993 - val_loss: 0.4571
# Epoch 17/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7987 - loss: 0.4739 - val_accuracy: 0.7989 - val_loss: 0.4557
# Epoch 18/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8016 - loss: 0.4714 - val_accuracy: 0.8005 - val_loss: 0.4538
# Epoch 19/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7996 - loss: 0.4651 - val_accuracy: 0.8035 - val_loss: 0.4510
# Epoch 20/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8005 - loss: 0.4678 - val_accuracy: 0.8039 - val_loss: 0.4495
# Epoch 21/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8003 - loss: 0.4661 - val_accuracy: 0.8035 - val_loss: 0.4483
# Epoch 22/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.
100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8173 - loss: 0.4207 - val_accuracy: 0.8251 - val_loss: 0.4105
# Epoch 91/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8134 - loss: 0.4267 - val_accuracy: 0.8239 - val_loss: 0.4104
# Epoch 92/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8166 - loss: 0.4156 - val_accuracy: 0.8262 - val_loss: 0.4093
# Epoch 93/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8171 - loss: 0.4225 - val_accuracy: 0.8262 - val_loss: 0.4092
# Epoch 94/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8173 - loss: 0.4245 - val_accuracy: 0.8266 - val_loss: 0.4089
# Epoch 95/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8132 - loss: 0.4227 - val_accuracy: 0.8273 - val_loss: 0.4087
# Epoch 96/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8192 - loss: 0.4204 - val_accuracy: 0.8270 - val_loss: 0.4084
# Epoch 97/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8169 - loss: 0.4206 - val_accuracy: 0.8262 - val_loss: 0.4077
# Epoch 98/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8205 - loss: 0.4148 - val_accuracy: 0.8281 - val_loss: 0.4070
# Epoch 99/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8194 - loss: 0.4197 - val_accuracy: 0.8289 - val_loss: 0.4067
# Epoch 100/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8169 - loss: 0.4177 - val_accuracy: 0.8289 - val_loss: 0.4063
# 1

# %% [markdown]
# ## 3. Visualizing Results

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.savefig("model_accuracy2.png")
mlflow.log_artifact("model_accuracy2.png")

plt.show()


print("model_history", model_history.history)

# Training and validation accuracy of model
final_train_accuracy = model_history.history['accuracy'][-1]
final_val_accuracy = model_history.history['val_accuracy'][-1]

mlflow.log_metric("final_train_accuracy", final_train_accuracy)
mlflow.log_metric("final_val_accuracy", final_val_accuracy)
# Out:
# model_history {'accuracy': [0.7648814916610718, 0.7906326055526733, 0.7934316396713257, 0.7952976226806641, 0.7958574295043945, 0.7956708073616028, 0.796417236328125, 0.7979100346565247, 0.7958574295043945, 0.7949244379997253, 0.7967904210090637, 0.8008956909179688, 0.7967904210090637, 0.7984698414802551, 0.7995894551277161, 0.8035081028938293, 0.7986564636230469, 0.801642119884491, 0.7995894551277161, 0.80052250623703, 0.8003358840942383, 0.8036947250366211, 0.8064937591552734, 0.8036947250366211, 0.8010823130607605, 0.8031349182128906, 0.8055607676506042, 0.8022019267082214, 0.8057473301887512, 0.8051875233650208, 0.8033215403556824, 0.8022019267082214, 0.8109722137451172, 0.8063071370124817, 0.804814338684082, 0.8072401285171509, 0.8061205744743347, 0.8068669438362122, 0.8119052052497864, 0.8096659779548645, 0.8109722137451172, 0.809106171131134, 0.8063071370124817, 0.8063071370124817, 0.8154506683349609, 0.8077999353408813, 0.8089195489883423, 0.8081731796264648, 0.8076133728027344, 0.8107855916023254, 0.8085463643074036, 0.8064937591552734, 0.8042545318603516, 0.8128381967544556, 0.8085463643074036, 0.8109722137451172, 0.8107855916023254, 0.8107855916023254, 0.8104124069213867, 0.8081731796264648, 0.8169434666633606, 0.8147042393684387, 0.8105989694595337, 0.8079865574836731, 0.8124650120735168, 0.8130248188972473, 0.8150774240493774, 0.8169434666633606, 0.8160104751586914, 0.8171300888061523, 0.8120918273925781, 0.8143310546875, 0.8096659779548645, 0.8150774240493774, 0.8117185831069946, 0.8137712478637695, 0.8124650120735168, 0.8152640461921692, 0.8135846257209778, 0.8169434666633606, 0.8109722137451172, 0.8104124069213867, 0.8122783899307251, 0.8178764581680298, 0.8171300888061523, 0.8141444325447083, 0.8148908615112305, 0.8178764581680298, 0.818809449672699, 0.8173166513442993, 0.813398003578186, 0.8165702819824219, 0.8171300888061523, 0.8173166513442993, 0.8132114410400391, 0.8191826939582825, 0.8169434666633606, 0.8204888701438904, 0.8193692564964294, 0.8169434666633606], 'loss': [0.6255708932876587, 0.5630571842193604, 0.5401970148086548, 0.5273745656013489, 0.5142496824264526, 0.5044358372688293, 0.5017369389533997, 0.49817749857902527, 0.49922317266464233, 0.48623818159103394, 0.48597434163093567, 0.4795660674571991, 0.4806266129016876, 0.48196712136268616, 0.4794768691062927, 0.47338712215423584, 0.47394055128097534, 0.4714374244213104, 0.4651327133178711, 0.4678178131580353, 0.4661039113998413, 0.46715226769447327, 0.45886674523353577, 0.46375739574432373, 0.45968499779701233, 0.46120601892471313, 0.4544817805290222, 0.4592980444431305, 0.45862096548080444, 0.4589378535747528, 0.45649462938308716, 0.45476704835891724, 0.45129555463790894, 0.44977521896362305, 0.45261603593826294, 0.4437313973903656, 0.4492664933204651, 0.4458555281162262, 0.44409289956092834, 0.4416022002696991, 0.4492175579071045, 0.4422893822193146, 0.4421263337135315, 0.4441739022731781, 0.4358648657798767, 0.4426416754722595, 0.439063161611557, 0.44701042771339417, 0.4399067461490631, 0.4424632787704468, 0.4374408721923828, 0.4400220811367035, 0.4438256621360779, 0.43454572558403015, 0.4353989064693451, 0.4357885420322418, 0.4327152669429779, 0.43250182271003723, 0.4372510313987732, 0.4383648931980133, 0.43637755513191223, 0.4345740079879761, 0.43316778540611267, 0.43629956245422363, 0.43663305044174194, 0.43299901485443115, 0.4284968972206116, 0.4272785186767578, 0.4316251277923584, 0.4270225763320923, 0.42853349447250366, 0.43268054723739624, 0.4345511198043823, 0.4291189908981323, 0.42780226469039917, 0.42915207147598267, 0.4247608184814453, 0.42471909523010254, 0.4296015202999115, 0.4278101921081543, 0.42278966307640076, 0.4326094388961792, 0.4253600239753723, 0.42414283752441406, 0.4272790849208832, 0.42460915446281433, 0.4217933714389801, 0.42425796389579773, 0.42057743668556213, 0.42071840167045593, 0.4267423748970032, 0.4156411588191986, 0.42252570390701294, 0.42450541257858276, 0.4227244257926941, 0.42037975788116455, 0.42058533430 ...

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')


plt.savefig("model_loss2.png")
mlflow.log_artifact("model_loss2.png")

plt.show()


# Training and validation loss of model
final_train_loss = model_history.history['loss'][-1]
final_val_loss = model_history.history['val_loss'][-1]

mlflow.log_metric("final_train_loss", final_train_loss)
mlflow.log_metric("final_val_loss", final_val_loss)

# %% [markdown]
# ## 4. Predictions & Evaluation
#
# ### Uses the trained ANN to predict probabilities on test data.
#
# #### Converts probabilities to True/False (churn if > 0.5).

# %%
y_pred_threshold = 0.5

y_pred = (classifier.predict(X_test) > y_pred_threshold)

mlflow.log_param("y_pred_threshold", y_pred_threshold)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 0.5

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
score = accuracy_score(y_test, y_pred)

# mlflow.log_metric("confusion_matrix of model", cm[0,0])
# mlflow.log_metric("confusion_matrix of model", cm[0,1])
# mlflow.log_metric("confusion_matrix of model", cm[1,0])
# mlflow.log_metric("confusion_matrix of model", cm[1,1])

# %%
print("Confusion Matrix:\n", cm)
print("Accuracy Score:", score)

mlflow.log_metric("test_set_accuracy", score)
# Out:
# Confusion Matrix:
#  [[1562   33]
#  [ 288  117]]
# Accuracy Score: 0.8395
