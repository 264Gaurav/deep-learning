# %% [markdown]
# # Dropout : (randomly droping few neurons while training the ANN model)
# ## And balancing that dropout by scaling the weights in inference(prediction/testing)
#
#
# ### Inverted Dropout (used in Keras, TensorFlow, PyTorch, etc.)
#
# During training, when a neuron survives dropout, its output is scaled by 1 / (1 - p).
#
# Example: If p=0.5, surviving outputs are multiplied by 2.
#
# This way, the expected value of the neuron stays the same as without dropout.
#
# ✅ At test time, no scaling is needed → Dropout is simply turned off.
#
#
# #### Modern frameworks (TF/Keras, PyTorch) use inverted dropout, so scaling is handled automatically during training.

# %% [markdown]
# ### 1. Data Preprocessing

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

datasetPath = '../data/Churn_Modelling.csv'

# %% [markdown]
# ### Use the DagsHub client to setup connection information for MLflow
# ### MLFlow - for experiment tracking

# %%
import dagshub
import mlflow
import time


#mlflow.set_tracking_uri("http://127.0.0.1:5000")
dagshub.init(repo_owner='264Gaurav', repo_name='deep-learning', mlflow=True)

# Set the experiment name
mlflow.set_experiment("ANN-p2")


# Start an MLflow run to log this execution
with mlflow.start_run() as run:
    run_id = run.info.run_id
    print(f"MLflow Run ID: {run_id}")

    mlflow.log_param("data set path", datasetPath)

    start_time = time.time()
    dataset = pd.read_csv(datasetPath) # extracted_data will be a list of Document objects
    end_time = time.time()
    loading_duration = end_time - start_time

    mlflow.log_metric("num_documents_loaded", len(dataset))
    mlflow.log_metric("pdf_loading_duration_seconds", loading_duration)


    print(f"MLflow Run ID: {run_id}")
    print(f"MLflow run finished. View at {mlflow.get_tracking_uri()}")
# Out:
# Accessing as 264Gaurav
# Initialized MLflow to track repo "264Gaurav/deep-learning"
# Repository 264Gaurav/deep-learning initialized!
# MLflow Run ID: ac6d422d51c5479eb846846e12fece5d
# MLflow Run ID: ac6d422d51c5479eb846846e12fece5d
# MLflow run finished. View at https://dagshub.com/264Gaurav/deep-learning.mlflow
# 🏃 View run enthused-elk-143 at: https://dagshub.com/264Gaurav/deep-learning.mlflow/#/experiments/3/runs/ac6d422d51c5479eb846846e12fece5d
# 🧪 View experiment at: https://dagshub.com/264Gaurav/deep-learning.mlflow/#/experiments/3

# %%
## Selects features (X) and target variable (y).
# iloc[:, 3:13] → takes columns 3 to 12 (customer info) as features.
# iloc[:, 13] → takes column 13 (whether the customer exited = churn) as labels.

X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %% [markdown]
# ### Replace categorical text data (Geography, Gender) with numeric columns that a (ANN) neural network can understand.
# #### get_dummies() converts categorical text values into numeric binary columns (one-hot encoding).

# %%
# Create dummy variables
geography = pd.get_dummies(X["Geography"], drop_first=True)
gender = pd.get_dummies(X['Gender'], drop_first=True)

# Concatenate the Data Frames
X = pd.concat([X, geography, gender], axis=1)

# Drop Unnecessary columns ## since, ANN needs numbers, not text so drop text/string columns
# Neural networks (and most ML algorithms) cannot work directly with text, they need numeric input.
# Solution: One-hot encoding (dummy variables)
X = X.drop(['Geography', 'Gender'], axis=1)

# %% [markdown]
# ### Splits the dataset into training (80%) and testing (20%) sets.

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split

testSetSize = 0.2
mlflow.log_param('Test set size', testSetSize)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=testSetSize, random_state=0
)

# %% [markdown]
# ### Feature scaling → standardizes data (mean = 0, std = 1).
#
# #### ANN performance improves when inputs are scaled.
#
# fit_transform → learns scaling from training data and applies it.
#
# transform → applies the same scaling to test data.

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## 2. Build the ANN!
#
# ### Import TensorFlow and Keras modules. (Now, keras is comes along with tensorflow 2.x)
#
# Sequential → linear stack of layers.
#
# Dense → fully connected (ANN) layer.
#
# Dropout → randomly drops neurons to reduce overfitting (optional).

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Initialising the ANN model as a sequential stack.
mlflow.log_param('ANN Model type', 'Sequential')
classifier = Sequential()

# %% [markdown]
# #### Adds the first hidden layer.
#
# units=6 → 6 neurons.
#
# kernel_initializer='he_uniform' → weight initialization method.
#
# activation='relu' → activation function (introduces non-linearity).
#
# input_dim=11 → number of input features (11 columns in X).

# %%
input_dim = X_train.shape[1]
units = 6
kernel_initializer = 'he_uniform'
activation = 'relu'
dropout = 0.3 # dropout to prevent overfitting and improve generalization of the model.

mlflow.log_param('input_dim', input_dim)
mlflow.log_param('units', units)
mlflow.log_param('kernel_initializer', kernel_initializer)
mlflow.log_param('activation', activation)
mlflow.log_param('Dropout value', dropout)

# Adding the input layer and the first hidden layer.
classifier.add(Dense(units=units, kernel_initializer=kernel_initializer ,activation=activation, input_dim=input_dim))
classifier.add(Dropout(dropout))
# Out:
# /Users/baqirrizvi/Desktop/ai/DeepLearning/deeplearning/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-08-31 23:57:36.149623: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-08-31 23:57:36.149760: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-08-31 23:57:36.149780: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-08-31 23:57:36.149830: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-08-31 23:57:36.149864: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
sec_units = 6
sec_kernel_initializer = 'he_uniform'
sec_activation = 'relu'

# Adding the second hidden layer.
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
classifier.add(Dropout(dropout))


mlflow.log_param('Total neurons in second hidden layer', sec_units)
mlflow.log_param('Second hidden layer activation', sec_activation)
mlflow.log_param('Second hidden layer kernel_initializer', sec_kernel_initializer)
# Out:
# 'he_uniform'

# %%
# third_units = 6
# third_kernel_initializer = 'he_uniform'
# third_activation = 'relu'

# # Adding the second hidden layer.
# classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
# classifier.add(Dropout(dropout))


# mlflow.log_param('Total neurons in third hidden layer', third_units)
# mlflow.log_param('Third hidden layer activation', third_activation)
# mlflow.log_param('Third hidden layer kernel_initializer', third_kernel_initializer)

# %%
out_units = 1
out_activation = 'sigmoid'
out_kernel_initializer = 'glorot_uniform'

## Adds the output layer.
# units=1 → single output neuron (binary classification: churn or not).
# activation='sigmoid' → outputs probability between 0 and 1.
classifier.add(Dense(units=out_units, kernel_initializer=out_kernel_initializer, activation=out_activation))

mlflow.log_param('Output layer units', out_units)
mlflow.log_param('Output layer activation', out_activation)
mlflow.log_param('Output layer kernel_initializer', out_kernel_initializer)
# Out:
# 'glorot_uniform'

# %% [markdown]
# #### Compiles the ANN (sets training configuration).
#
# optimizer='adamax' → optimization algorithm.
#
# loss='binary_crossentropy' → loss function for binary classification.
#
# metrics=['accuracy'] → track accuracy during training.

# %%
optimizer = 'adamax'
loss = 'binary_crossentropy'
metrics = ['accuracy']

classifier.compile(optimizer='adamax', loss='binary_crossentropy', metrics=['accuracy'])

mlflow.log_param('optimizer for ANN', 'adamax')
mlflow.log_param('loss function for ANN', 'binary_crossentropy')
mlflow.log_param('metrics for ANN', metrics)
# Out:
# ['accuracy']

# %% [markdown]
# #### Trains the ANN on training data.
#
# validation_split=0.33 → uses 33% of training data for validation.
#
# batch_size=10 → updates weights after every 10 samples.
#
# epochs=100 → number of training iterations over the dataset.
#
# verbose=1 → prints progress.
#
# ###### model_history stores loss/accuracy values for plotting later.

# %% [markdown]
# ### classifier.fit(...)
#
# This is the method that trains the model on the data.
#
# It adjusts the weights of your ANN using backpropagation + optimizer (Adamax in our case).
#
# ### validation_split=0.33
#
# 33% of the training data is reserved for validation.
#
# Validation data is not used to train weights, only to check performance after each epoch.
#
# Helps detect overfitting (when training accuracy is high but validation accuracy is low).
#
# ### batch_size=10
#
# Training data is split into mini-batches of 10 samples.
#
# The ANN updates its weights after each batch (not after the whole dataset).
#
# Why? → Speeds up training and makes gradient descent more stable.
#
# ### epochs=100
#
# The model will go through the entire training dataset 100 times.
#
# More epochs = more chances to learn, but also risk of overfitting.
#
# Each epoch consists of multiple batch updates.
#
# ### verbose=1
#
# Controls the training output:
#
# 0 → silent
#
# 1 → progress bar for each epoch (default)
#
# 2 → one line per epoch
#
# ### model_history
#
# Stores training history in a dictionary format.

# %%
validation_split = 0.33
batch_size = 10
epochs = 100
verbose = 1

model_history = classifier.fit(
    X_train, y_train, validation_split=validation_split,
    batch_size=batch_size, epochs=epochs, verbose=verbose
)

mlflow.log_param('batch_size', batch_size)
mlflow.log_param('epochs', epochs)
mlflow.log_param('validation_split', validation_split)
mlflow.log_param('verbose', verbose)
# Out:
# Epoch 1/100
# 2025-08-31 23:57:44.389709: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5514 - loss: 0.9318 - val_accuracy: 0.7119 - val_loss: 0.5863
# Epoch 2/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6535 - loss: 0.7216 - val_accuracy: 0.7929 - val_loss: 0.5160
# Epoch 3/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7167 - loss: 0.6168 - val_accuracy: 0.7929 - val_loss: 0.4933
# Epoch 4/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7348 - loss: 0.5797 - val_accuracy: 0.7940 - val_loss: 0.4860
# Epoch 5/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7570 - loss: 0.5608 - val_accuracy: 0.7944 - val_loss: 0.4847
# Epoch 6/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7679 - loss: 0.5414 - val_accuracy: 0.7955 - val_loss: 0.4838
# Epoch 7/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7759 - loss: 0.5255 - val_accuracy: 0.7948 - val_loss: 0.4819
# Epoch 8/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7774 - loss: 0.5199 - val_accuracy: 0.7948 - val_loss: 0.4801
# Epoch 9/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7876 - loss: 0.5062 - val_accuracy: 0.7948 - val_loss: 0.4782
# Epoch 10/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7895 - loss: 0.5080 - val_accuracy: 0.7948 - val_loss: 0.4773
# Epoch 11/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7862 - loss: 0.5004 - val_accuracy: 0.7948 - val_loss: 0.4754
# Epoch 12/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7886 - loss: 0.4923 - val_accuracy: 0.7948 - val_loss: 0.4732
# Epoch 13/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7925 - loss: 0.4939 - val_accuracy: 0.7936 - val_loss: 0.4710
# Epoch 14/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7901 - loss: 0.4934 - val_accuracy: 0.7940 - val_loss: 0.4699
# Epoch 15/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7962 - loss: 0.4803 - val_accuracy: 0.7917 - val_loss: 0.4667
# Epoch 16/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7934 - loss: 0.4839 - val_accuracy: 0.7925 - val_loss: 0.4658
# Epoch 17/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7908 - loss: 0.4861 - val_accuracy: 0.7910 - val_loss: 0.4642
# Epoch 18/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7942 - loss: 0.4750 - val_accuracy: 0.7891 - val_loss: 0.4619
# Epoch 19/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7901 - loss: 0.4811 - val_accuracy: 0.7910 - val_loss: 0.4613
# Epoch 20/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7944 - loss: 0.4702 - val_accuracy: 0.7891 - val_loss: 0.4586
# Epoch 21/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.
100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7987 - loss: 0.4513 - val_accuracy: 0.7944 - val_loss: 0.4421
# Epoch 90/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7946 - loss: 0.4523 - val_accuracy: 0.7940 - val_loss: 0.4425
# Epoch 91/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.7962 - loss: 0.4544 - val_accuracy: 0.7917 - val_loss: 0.4442
# Epoch 92/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7983 - loss: 0.4504 - val_accuracy: 0.7948 - val_loss: 0.4414
# Epoch 93/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7966 - loss: 0.4509 - val_accuracy: 0.7944 - val_loss: 0.4423
# Epoch 94/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7983 - loss: 0.4481 - val_accuracy: 0.7952 - val_loss: 0.4409
# Epoch 95/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7959 - loss: 0.4478 - val_accuracy: 0.7944 - val_loss: 0.4412
# Epoch 96/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7977 - loss: 0.4504 - val_accuracy: 0.7952 - val_loss: 0.4418
# Epoch 97/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8007 - loss: 0.4490 - val_accuracy: 0.7929 - val_loss: 0.4432
# Epoch 98/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7940 - loss: 0.4543 - val_accuracy: 0.7929 - val_loss: 0.4429
# Epoch 99/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7998 - loss: 0.4505 - val_accuracy: 0.7936 - val_loss: 0.4441
# Epoch 100/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7944 - loss: 0.4578 - val_accuracy: 0.7948 - val_loss: 0.4414
# 1

# %% [markdown]
# ## 3. Visualizing Results

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.savefig("model_accuracy2.png")
mlflow.log_artifact("model_accuracy2.png")

plt.show()


print("model_history", model_history.history)

# Training and validation accuracy of model
final_train_accuracy = model_history.history['accuracy'][-1]
final_val_accuracy = model_history.history['val_accuracy'][-1]

mlflow.log_metric("final_train_accuracy", final_train_accuracy)
mlflow.log_metric("final_val_accuracy", final_val_accuracy)
# Out:
# model_history {'accuracy': [0.5514088273048401, 0.6534801125526428, 0.716738224029541, 0.734838604927063, 0.7570441961288452, 0.7678671479225159, 0.7758910059928894, 0.7773838639259338, 0.7876469492912292, 0.7895129919052124, 0.7861541509628296, 0.7885799407958984, 0.7924985885620117, 0.7900727987289429, 0.7962306141853333, 0.7934316396713257, 0.7908191680908203, 0.7941780090332031, 0.7900727987289429, 0.7943646311759949, 0.7960440516471863, 0.7904459834098816, 0.7947378158569336, 0.7977234721183777, 0.7973502278327942, 0.796417236328125, 0.7949244379997253, 0.8001492619514465, 0.7960440516471863, 0.7958574295043945, 0.7999626994132996, 0.7960440516471863, 0.7982832789421082, 0.796417236328125, 0.7928718328475952, 0.7971636652946472, 0.7997760772705078, 0.7990296483039856, 0.7960440516471863, 0.800709068775177, 0.7952976226806641, 0.8001492619514465, 0.7952976226806641, 0.7982832789421082, 0.7979100346565247, 0.7926852107048035, 0.8014554977416992, 0.7990296483039856, 0.7986564636230469, 0.7971636652946472, 0.7971636652946472, 0.7966038584709167, 0.7990296483039856, 0.7966038584709167, 0.7956708073616028, 0.801642119884491, 0.7960440516471863, 0.7952976226806641, 0.7992162704467773, 0.7971636652946472, 0.7952976226806641, 0.7992162704467773, 0.7994028925895691, 0.7990296483039856, 0.7938048243522644, 0.7969770431518555, 0.7984698414802551, 0.7977234721183777, 0.8003358840942383, 0.7984698414802551, 0.7971636652946472, 0.7958574295043945, 0.7949244379997253, 0.7960440516471863, 0.7967904210090637, 0.7975368499755859, 0.7973502278327942, 0.7966038584709167, 0.7973502278327942, 0.7994028925895691, 0.7951110005378723, 0.7988430857658386, 0.7990296483039856, 0.7947378158569336, 0.7936182022094727, 0.80052250623703, 0.7994028925895691, 0.7967904210090637, 0.7986564636230469, 0.7945511937141418, 0.7962306141853333, 0.7982832789421082, 0.7966038584709167, 0.7982832789421082, 0.7958574295043945, 0.7977234721183777, 0.800709068775177, 0.7939913868904114, 0.7997760772705078, 0.7943646311759949], 'loss': [0.9317805767059326, 0.721608579158783, 0.6167973875999451, 0.579666018486023, 0.5608367323875427, 0.5414110422134399, 0.5254762768745422, 0.519893229007721, 0.506155788898468, 0.5080180764198303, 0.5003973245620728, 0.49231666326522827, 0.4938758909702301, 0.4933609962463379, 0.4803248941898346, 0.4839112162590027, 0.48608019948005676, 0.4750113785266876, 0.48111438751220703, 0.4702276587486267, 0.4720247685909271, 0.47410205006599426, 0.4680234491825104, 0.46544864773750305, 0.46470287442207336, 0.4644595980644226, 0.46329987049102783, 0.46358081698417664, 0.46151551604270935, 0.4651971459388733, 0.46255606412887573, 0.46393314003944397, 0.4591681957244873, 0.4571940302848816, 0.4592622220516205, 0.4600618779659271, 0.45774292945861816, 0.45683345198631287, 0.46070653200149536, 0.452659010887146, 0.46085336804389954, 0.4538050889968872, 0.46104058623313904, 0.4573013484477997, 0.45777204632759094, 0.45628228783607483, 0.4521580934524536, 0.4557332694530487, 0.4498881697654724, 0.4548405110836029, 0.4518929123878479, 0.45477306842803955, 0.4503810405731201, 0.4545558989048004, 0.455243855714798, 0.45322704315185547, 0.45709872245788574, 0.45575737953186035, 0.4531659185886383, 0.4485255479812622, 0.45424360036849976, 0.4508705139160156, 0.45339372754096985, 0.45294806361198425, 0.4575522541999817, 0.45049721002578735, 0.4558890461921692, 0.4523727595806122, 0.4481903910636902, 0.4505375027656555, 0.45254427194595337, 0.45129597187042236, 0.452366441488266, 0.45079779624938965, 0.4525645077228546, 0.45461124181747437, 0.45334455370903015, 0.4499262571334839, 0.45302048325538635, 0.44751301407814026, 0.4557044804096222, 0.45315954089164734, 0.45030099153518677, 0.45674246549606323, 0.45165586471557617, 0.44987136125564575, 0.4486261010169983, 0.4551573097705841, 0.45125487446784973, 0.45230305194854736, 0.4543938636779785, 0.4504148066043854, 0.45087170600891113, 0.4481271207332611, 0.4477977752685547, 0.45036980509757996, 0.44896954298019 ...

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')


plt.savefig("model_loss2.png")
mlflow.log_artifact("model_loss2.png")

plt.show()


# Training and validation loss of model
final_train_loss = model_history.history['loss'][-1]
final_val_loss = model_history.history['val_loss'][-1]

mlflow.log_metric("final_train_loss", final_train_loss)
mlflow.log_metric("final_val_loss", final_val_loss)

# %% [markdown]
# ## 4. Predictions & Evaluation
#
# ### Uses the trained ANN to predict probabilities on test data.
#
# #### Converts probabilities to True/False (churn if > 0.5).

# %%
y_pred_threshold = 0.5

y_pred = (classifier.predict(X_test) > y_pred_threshold)

mlflow.log_param("y_pred_threshold", y_pred_threshold)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0.5

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
score = accuracy_score(y_test, y_pred)

# mlflow.log_metric("confusion_matrix of model", cm[0,0])
# mlflow.log_metric("confusion_matrix of model", cm[0,1])
# mlflow.log_metric("confusion_matrix of model", cm[1,0])
# mlflow.log_metric("confusion_matrix of model", cm[1,1])

# %%
print("Confusion Matrix:\n", cm)
print("Accuracy Score:", score)

mlflow.log_metric("test_set_accuracy", score)
# Out:
# Confusion Matrix:
#  [[1538   57]
#  [ 352   53]]
# Accuracy Score: 0.7955
