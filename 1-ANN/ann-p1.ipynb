# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# TensorFlow version: 2.16.2
# Num GPUs Available: 1

# %% [markdown]
# ## 1. Data Preprocessing

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

datasetPath = '../data/Churn_Modelling.csv'

# %% [markdown]
# ## Use the DagsHub client to setup connection information for MLflow
# ### MLFlow - for experiment tracking

# %%
import mlflow

mlflow.end_run()

# %%
import dagshub
import mlflow
import time


#mlflow.set_tracking_uri("http://127.0.0.1:5000")
dagshub.init(repo_owner='264Gaurav', repo_name='deep-learning', mlflow=True)

# Set the experiment name
mlflow.set_experiment("ANN-p1")


# Start an MLflow run to log this execution
with mlflow.start_run() as run:
    run_id = run.info.run_id
    print(f"MLflow Run ID: {run_id}")

    mlflow.log_param("data set path", datasetPath)

    start_time = time.time()
    dataset = pd.read_csv(datasetPath) # extracted_data will be a list of Document objects
    end_time = time.time()
    loading_duration = end_time - start_time

    mlflow.log_metric("num_documents_loaded", len(dataset))
    mlflow.log_metric("pdf_loading_duration_seconds", loading_duration)


    print(f"MLflow Run ID: {run_id}")
    print(f"MLflow run finished. View at {mlflow.get_tracking_uri()}")
# Out:
# Accessing as 264Gaurav
# Initialized MLflow to track repo "264Gaurav/deep-learning"
# Repository 264Gaurav/deep-learning initialized!
# MLflow Run ID: 3f419702da424dc8bd85b8510fbf35f3
# MLflow Run ID: 3f419702da424dc8bd85b8510fbf35f3
# MLflow run finished. View at https://dagshub.com/264Gaurav/deep-learning.mlflow
# 🏃 View run mysterious-wren-576 at: https://dagshub.com/264Gaurav/deep-learning.mlflow/#/experiments/2/runs/3f419702da424dc8bd85b8510fbf35f3
# 🧪 View experiment at: https://dagshub.com/264Gaurav/deep-learning.mlflow/#/experiments/2

# %%
## Selects features (X) and target variable (y).
# iloc[:, 3:13] → takes columns 3 to 12 (customer info) as features.
# iloc[:, 13] → takes column 13 (whether the customer exited = churn) as labels.

X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %% [markdown]
# ### Replace categorical text data (Geography, Gender) with numeric columns that a (ANN) neural network can understand.
# #### get_dummies() converts categorical text values into numeric binary columns (one-hot encoding).
#
# Example with "Geography" column:
#
# | France | Spain | Germany |
# | ------ | ----- | ------- |
# | 1      | 0     | 0       |
# | 0      | 1     | 0       |
# | 0      | 0     | 1       |
# | 1      | 0     | 0       |
#
# After drop_first = True
#
# | Spain | Germany |                            |
# | ----- | ------- | -------------------------- |
# | 0     | 0       | (→ France is implied here) |
# | 1     | 0       |                            |
# | 0     | 1       |                            |
# | 0     | 0       |                            |
#
#
#
# #### 👉 Now: If both Spain=0 and Germany=0, it means France.
#
#
# ### Same logic for Gender
#
# "Gender" originally has Male and Female.
#
# With drop_first=True, we keep only Male (for example):
#
# | Male |
# | ---- |
# | 1    |
# | 0    |
#
#
# 👉 If Male=1 → person is male.
# 👉 If Male=0 → person is female.

# %%
# Create dummy variables
geography = pd.get_dummies(X["Geography"], drop_first=True)
gender = pd.get_dummies(X['Gender'], drop_first=True)

# Concatenate the Data Frames
X = pd.concat([X, geography, gender], axis=1)

# Drop Unnecessary columns ## since, ANN needs numbers, not text so drop text/string columns
# Neural networks (and most ML algorithms) cannot work directly with text, they need numeric input.
# Solution: One-hot encoding (dummy variables)
X = X.drop(['Geography', 'Gender'], axis=1)

# %% [markdown]
# ### Splits the dataset into training (80%) and testing (20%) sets.

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split

testSetSize = 0.2
mlflow.log_param('Test set size', testSetSize)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=testSetSize, random_state=0
)

# %% [markdown]
# ### Feature scaling → standardizes data (mean = 0, std = 1).
#
# #### ANN performance improves when inputs are scaled.
#
# fit_transform → learns scaling from training data and applies it.
#
# transform → applies the same scaling to test data.

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## 2. Build the ANN!
#
# ### Import TensorFlow and Keras modules. (Now, keras is comes along with tensorflow 2.x)
#
# Sequential → linear stack of layers.
#
# Dense → fully connected (ANN) layer.
#
# Dropout → randomly drops neurons to reduce overfitting (optional).

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Initialising the ANN model as a sequential stack.
mlflow.log_param('ANN Model type', 'Sequential')
classifier = Sequential()

# %% [markdown]
# #### Adds the first hidden layer.
#
# units=6 → 6 neurons.
#
# kernel_initializer='he_uniform' → weight initialization method.
#
# activation='relu' → activation function (introduces non-linearity).
#
# input_dim=11 → number of input features (11 columns in X).

# %%
input_dim = X_train.shape[1]
units = 6
kernel_initializer = 'he_uniform'
activation = 'relu'

mlflow.log_param('input_dim', input_dim)
mlflow.log_param('units', units)
mlflow.log_param('kernel_initializer', kernel_initializer)
mlflow.log_param('activation', activation)

# Adding the input layer and the first hidden layer.
classifier.add(Dense(units=units, kernel_initializer=kernel_initializer ,activation=activation, input_dim=input_dim))
# Out:
# /Users/baqirrizvi/Desktop/ai/DeepLearning/deeplearning/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-09-01 00:03:27.571337: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-09-01 00:03:27.571363: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-09-01 00:03:27.571371: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-09-01 00:03:27.571384: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-09-01 00:03:27.571393: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
sec_units = 6
sec_kernel_initializer = 'he_uniform'
sec_activation = 'relu'

# Adding the second hidden layer.
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))


mlflow.log_param('Total neurons in second hidden layer', sec_units)
mlflow.log_param('Second hidden layer activation', sec_activation)
mlflow.log_param('Second hidden layer kernel_initializer', sec_kernel_initializer)
# Out:
# 'he_uniform'

# %%
third_units = 6
third_kernel_initializer = 'he_uniform'
third_activation = 'relu'

# Adding the second hidden layer.
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))


mlflow.log_param('Total neurons in third hidden layer', third_units)
mlflow.log_param('Third hidden layer activation', third_activation)
mlflow.log_param('Third hidden layer kernel_initializer', third_kernel_initializer)
# Out:
# 'he_uniform'

# %%
out_units = 1
out_activation = 'sigmoid'
out_kernel_initializer = 'glorot_uniform'

## Adds the output layer.
# units=1 → single output neuron (binary classification: churn or not).
# activation='sigmoid' → outputs probability between 0 and 1.
classifier.add(Dense(units=out_units, kernel_initializer=out_kernel_initializer, activation=out_activation))

mlflow.log_param('Output layer units', out_units)
mlflow.log_param('Output layer activation', out_activation)
mlflow.log_param('Output layer kernel_initializer', out_kernel_initializer)
# Out:
# 'glorot_uniform'

# %% [markdown]
# #### Compiles the ANN (sets training configuration).
#
# optimizer='adamax' → optimization algorithm.
#
# loss='binary_crossentropy' → loss function for binary classification.
#
# metrics=['accuracy'] → track accuracy during training.

# %%
optimizer = 'adamax'
loss = 'binary_crossentropy'
metrics = ['accuracy']

classifier.compile(optimizer='adamax', loss='binary_crossentropy', metrics=['accuracy'])

mlflow.log_param('optimizer for ANN', 'adamax')
mlflow.log_param('loss function for ANN', 'binary_crossentropy')
mlflow.log_param('metrics for ANN', metrics)
# Out:
# ['accuracy']

# %% [markdown]
# #### Trains the ANN on training data.
#
# validation_split=0.33 → uses 33% of training data for validation.
#
# batch_size=10 → updates weights after every 10 samples.
#
# epochs=100 → number of training iterations over the dataset.
#
# verbose=1 → prints progress.
#
# ###### model_history stores loss/accuracy values for plotting later.

# %% [markdown]
# ### classifier.fit(...)
#
# This is the method that trains the model on the data.
#
# It adjusts the weights of your ANN using backpropagation + optimizer (Adamax in our case).
#
# ### validation_split=0.33
#
# 33% of the training data is reserved for validation.
#
# Validation data is not used to train weights, only to check performance after each epoch.
#
# Helps detect overfitting (when training accuracy is high but validation accuracy is low).
#
# ### batch_size=10
#
# Training data is split into mini-batches of 10 samples.
#
# The ANN updates its weights after each batch (not after the whole dataset).
#
# Why? → Speeds up training and makes gradient descent more stable.
#
# ### epochs=100
#
# The model will go through the entire training dataset 100 times.
#
# More epochs = more chances to learn, but also risk of overfitting.
#
# Each epoch consists of multiple batch updates.
#
# ### verbose=1
#
# Controls the training output:
#
# 0 → silent
#
# 1 → progress bar for each epoch (default)
#
# 2 → one line per epoch
#
# ### model_history
#
# Stores training history in a dictionary format.

# %%
validation_split = 0.33
batch_size = 10
epochs = 100
verbose = 1

model_history = classifier.fit(
    X_train, y_train, validation_split=validation_split,
    batch_size=batch_size, epochs=epochs, verbose=verbose
)

mlflow.log_param('batch_size', batch_size)
mlflow.log_param('epochs', epochs)
mlflow.log_param('validation_split', validation_split)
mlflow.log_param('verbose', verbose)
# Out:
# Epoch 1/100
# 2025-09-01 00:03:37.978335: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6845 - loss: 0.6095 - val_accuracy: 0.7766 - val_loss: 0.5200
# Epoch 2/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7987 - loss: 0.4876 - val_accuracy: 0.7986 - val_loss: 0.4809
# Epoch 3/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8005 - loss: 0.4668 - val_accuracy: 0.8001 - val_loss: 0.4686
# Epoch 4/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8037 - loss: 0.4568 - val_accuracy: 0.8020 - val_loss: 0.4620
# Epoch 5/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8043 - loss: 0.4499 - val_accuracy: 0.8058 - val_loss: 0.4566
# Epoch 6/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8095 - loss: 0.4452 - val_accuracy: 0.8080 - val_loss: 0.4523
# Epoch 7/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.
100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8085 - loss: 0.4841 - val_accuracy: 0.7357 - val_loss: 0.5882
# Epoch 99/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7996 - loss: 0.5034 - val_accuracy: 0.8016 - val_loss: 0.4569
# Epoch 100/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8037 - loss: 0.4744 - val_accuracy: 0.8133 - val_loss: 0.5503
# 1

# %% [markdown]
# ## 3. Visualizing Results

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')


plt.savefig("model_accuracy.png")
mlflow.log_artifact("model_accuracy.png")

plt.show()

print("model_history", model_history.history)

# Training and validation accuracy of model
final_train_accuracy = model_history.history['accuracy'][-1]
final_val_accuracy = model_history.history['val_accuracy'][-1]

mlflow.log_metric("final_train_accuracy", final_train_accuracy)
mlflow.log_metric("final_val_accuracy", final_val_accuracy)
# Out:
# model_history {'accuracy': [0.6844560503959656, 0.7986564636230469, 0.80052250623703, 0.8036947250366211, 0.8042545318603516, 0.8094793558120728, 0.8113453984260559, 0.8111587762832642, 0.8124650120735168, 0.8111587762832642, 0.8119052052497864, 0.8126516342163086, 0.8117185831069946, 0.8156372308731079, 0.8143310546875, 0.8147042393684387, 0.8147042393684387, 0.8128381967544556, 0.8126516342163086, 0.8141444325447083, 0.8160104751586914, 0.8130248188972473, 0.8150774240493774, 0.8126516342163086, 0.8135846257209778, 0.8147042393684387, 0.8141444325447083, 0.8137712478637695, 0.8119052052497864, 0.8165702819824219, 0.8150774240493774, 0.8158238530158997, 0.814517617225647, 0.8139578104019165, 0.8119052052497864, 0.8109722137451172, 0.8109722137451172, 0.8132114410400391, 0.8161970376968384, 0.8160104751586914, 0.8150774240493774, 0.813398003578186, 0.8135846257209778, 0.8117185831069946, 0.8137712478637695, 0.8111587762832642, 0.8113453984260559, 0.8130248188972473, 0.8109722137451172, 0.8152640461921692, 0.8122783899307251, 0.8107855916023254, 0.8120918273925781, 0.8081731796264648, 0.8126516342163086, 0.8100391626358032, 0.8104124069213867, 0.8126516342163086, 0.8115320205688477, 0.810225784778595, 0.8072401285171509, 0.8109722137451172, 0.8085463643074036, 0.8083597421646118, 0.8104124069213867, 0.8128381967544556, 0.8132114410400391, 0.8076133728027344, 0.8111587762832642, 0.8089195489883423, 0.8104124069213867, 0.8135846257209778, 0.8077999353408813, 0.8117185831069946, 0.8053741455078125, 0.8087329864501953, 0.8038813471794128, 0.8124650120735168, 0.8120918273925781, 0.8111587762832642, 0.8064937591552734, 0.8081731796264648, 0.8083597421646118, 0.8107855916023254, 0.8036947250366211, 0.8105989694595337, 0.8074267506599426, 0.8113453984260559, 0.8050009608268738, 0.8105989694595337, 0.8066803216934204, 0.8077999353408813, 0.8111587762832642, 0.8122783899307251, 0.8085463643074036, 0.8038813471794128, 0.8079865574836731, 0.8085463643074036, 0.7995894551277161, 0.8036947250366211], 'loss': [0.6095438599586487, 0.48761430382728577, 0.46680498123168945, 0.4567662477493286, 0.4499288499355316, 0.44521692395210266, 0.4416481554508209, 0.43911200761795044, 0.4370991289615631, 0.43583858013153076, 0.4342363476753235, 0.43279537558555603, 0.4326711595058441, 0.4310399889945984, 0.4301490783691406, 0.4304909110069275, 0.4299857020378113, 0.42948946356773376, 0.4294604957103729, 0.42876049876213074, 0.42817404866218567, 0.4274047613143921, 0.42817679047584534, 0.4288111627101898, 0.4279608428478241, 0.4279346466064453, 0.4285706579685211, 0.4285276532173157, 0.43012315034866333, 0.42890146374702454, 0.43042707443237305, 0.4294435977935791, 0.42946290969848633, 0.43020525574684143, 0.4322945177555084, 0.4326881170272827, 0.43035227060317993, 0.43047499656677246, 0.4319832921028137, 0.43235212564468384, 0.43203413486480713, 0.4319877326488495, 0.4320724606513977, 0.4319888651371002, 0.43219485878944397, 0.43379056453704834, 0.4335819482803345, 0.43621698021888733, 0.436107873916626, 0.43962183594703674, 0.43810394406318665, 0.437421053647995, 0.4376348853111267, 0.4428994357585907, 0.43658289313316345, 0.444657564163208, 0.44606155157089233, 0.44620996713638306, 0.4373427927494049, 0.4397711157798767, 0.4448634386062622, 0.43976476788520813, 0.44244012236595154, 0.4532153904438019, 0.44806596636772156, 0.4453691244125366, 0.4502764642238617, 0.44435590505599976, 0.4503975510597229, 0.45050182938575745, 0.4509844183921814, 0.4454359710216522, 0.45209938287734985, 0.44906991720199585, 0.4562138319015503, 0.4510568082332611, 0.45905518531799316, 0.4579654037952423, 0.4565332233905792, 0.463283509016037, 0.4657602310180664, 0.460758239030838, 0.48126599192619324, 0.4664587378501892, 0.4743996858596802, 0.47110220789909363, 0.4863484501838684, 0.4600898325443268, 0.4796462655067444, 0.47312358021736145, 0.4787307381629944, 0.4705391228199005, 0.4725193381309509, 0.48712456226348877, 0.48016154766082764, 0.4892808496952057, 0.4681613147258 ...

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')


plt.savefig("model_loss.png")
mlflow.log_artifact("model_loss.png")

plt.show()

# Training and validation loss of model
final_train_loss = model_history.history['loss'][-1]
final_val_loss = model_history.history['val_loss'][-1]

mlflow.log_metric("final_train_loss", final_train_loss)
mlflow.log_metric("final_val_loss", final_val_loss)

# %% [markdown]
# ## 4. Predictions & Evaluation
#
# ### Uses the trained ANN to predict probabilities on test data.
#
# #### Converts probabilities to True/False (churn if > 0.5).

# %%
y_pred_threshold = 0.5

y_pred = (classifier.predict(X_test) > y_pred_threshold)

mlflow.log_param("y_pred_threshold", y_pred_threshold)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0.5

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
score = accuracy_score(y_test, y_pred)

# mlflow.log_metric("confusion_matrix of model", cm[0,0])
# mlflow.log_metric("confusion_matrix of model", cm[0,1])
# mlflow.log_metric("confusion_matrix of model", cm[1,0])
# mlflow.log_metric("confusion_matrix of model", cm[1,1])

# %%
print("Confusion Matrix:\n", cm)
print("Accuracy Score:", score)

mlflow.log_metric("test_set_accuracy", score)
# Out:
# Confusion Matrix:
#  [[1576   19]
#  [ 346   59]]
# Accuracy Score: 0.8175
